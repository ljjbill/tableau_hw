# %%
import pandas as pd

# %%
csv_file1 = "JC-201803-citibike-tripdata.csv"
csv_file2 = "JC-201804-citibike-tripdata.csv"
csv_file3 = "JC-201805-citibike-tripdata.csv"
csv_file4 = "JC-201806-citibike-tripdata.csv"
csv_file5 = "JC-201807-citibike-tripdata.csv"
csv_file6 = "JC-201808-citibike-tripdata.csv"
csv_file7 = "JC-201809-citibike-tripdata.csv"
csv_file8 = "JC-201810-citibike-tripdata.csv"
csv_file9 = "JC-201811-citibike-tripdata.csv"
csv_file10 = "JC-201812-citibike-tripdata.csv"
csv_file11 = "JC-201901-citibike-tripdata.csv"
csv_file12 = "JC-201902-citibike-tripdata.csv"

bike_data_df1 = pd.read_csv(csv_file1)
bike_data_df2 = pd.read_csv(csv_file2)
bike_data_df3 = pd.read_csv(csv_file3)
bike_data_df4 = pd.read_csv(csv_file4)
bike_data_df5 = pd.read_csv(csv_file5)
bike_data_df6 = pd.read_csv(csv_file6)
bike_data_df7 = pd.read_csv(csv_file7)
bike_data_df8 = pd.read_csv(csv_file8)
bike_data_df9 = pd.read_csv(csv_file9)
bike_data_df10 = pd.read_csv(csv_file10)
bike_data_df11 = pd.read_csv(csv_file11)
bike_data_df12 = pd.read_csv(csv_file12)

merged_df=pd.concat([bike_data_df1,bike_data_df2,bike_data_df3,bike_data_df4,bike_data_df5,bike_data_df6,bike_data_df7,bike_data_df8,bike_data_df9,bike_data_df10,bike_data_df11,bike_data_df12],ignore_index=True)

merged_df.ftypes
# Out:
# tripduration                 int64:dense
# starttime                   object:dense
# stoptime                    object:dense
# start station id             int64:dense
# start station name          object:dense
# start station latitude     float64:dense
# start station longitude    float64:dense
# end station id               int64:dense
# end station name            object:dense
# end station latitude       float64:dense
# end station longitude      float64:dense
# bikeid                       int64:dense
# usertype                    object:dense
# birth year                   int64:dense
# gender                       int64:dense
# dtype: object

# %%
merged_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
merged_df = merged_df.reset_index()
merged_df['Trip_ID'] = merged_df.index + 200
merged_df['Month']=merged_df['starttime'].str[:7]

# %%
merged_df.head()
# Out:
#    index  tripduration                 starttime                  stoptime  \
# 0      0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1      1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2      2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3      3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4      4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
merged_df.to_csv("rawdata.csv", index=False, header=True)
